# %%
import pandas as pd

# %%
df = pd.read_csv('Test_sorted.csv')

# %%
df.head(5)
# Out:
#    East_Midlands_price  Eastern_England_price  London_price  \
# 0            35.071785              37.717785     35.797230
# 1            38.851785              41.686785     38.851785
# 2            35.533785              38.200785     35.797230
# 3            33.874785              36.457785     35.797230
# 4            33.018090              35.056875     35.797230
#
#    Merseyside_and_Northern_Wales_price  North_Western_England_price  \
# 0                            40.363785                    37.717785
# 1                            44.521785                    41.686785
# 2                            40.867785                    38.200785
# 3                            39.051285                    36.457785
# 4                            36.940785                    34.452285
#
#    Northern_Scotland_price  South_Western_England_price  \
# 0                45.655785                    43.009785
# 1                50.191785                    47.356785
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9888 entries, 0 to 9887
# Columns: 251 entries, East_Midlands_price to elevationSouthhampton - Portsmouth_weather
# dtypes: float64(251)
# memory usage: 18.9 MB

# %%
df.isna()
# Out:
#       East_Midlands_price  Eastern_England_price  London_price  \
# 0                   False                  False         False
# 1                   False                  False         False
# 2                   False                  False         False
# 3                   False                  False         False
# 4                   False                  False         False
# ...                   ...                    ...           ...
# 9883                False                  False         False
# 9884                False                  False         False
# 9885                False                  False         False
# 9886                False                  False         False
# 9887                False                  False         False
#
#       Merseyside_and_Northern_Wales_price  North_Western_England_price  \
# 0                                   False                        False
# ...
